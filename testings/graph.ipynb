# %%
import pandas as pd

# %%
df = pd.read_csv("../data.csv")

# %%
df
# Out:
#      angry0  angry1                box0 box1  disgust0  disgust1  fear0  \
# 0      0.04     NaN   [220, 77, 74, 93]  NaN       0.0       NaN   0.02
# 1      0.03     NaN   [221, 79, 77, 97]  NaN       0.0       NaN   0.02
# 2      0.04     NaN   [219, 77, 76, 97]  NaN       0.0       NaN   0.01
# 3      0.08     NaN   [219, 77, 75, 97]  NaN       0.0       NaN   0.02
# 4      0.09     NaN   [220, 80, 77, 98]  NaN       0.0       NaN   0.02
# ..      ...     ...                 ...  ...       ...       ...    ...
# 251    0.11     NaN  [236, 69, 83, 106]  NaN       0.0       NaN   0.04
# 252    0.06     NaN  [231, 65, 86, 112]  NaN       0.0       NaN   0.02
# 253    0.23     NaN  [230, 64, 85, 112]  NaN       0.0       NaN   0.05
# 254    0.04     NaN  [227, 67, 84, 108]  NaN       0.0       NaN   0.03
# 255    0.21     NaN  [224, 68, 85, 106]  NaN       0.0       NaN   0.06
#
#      fear1  happy0  happy1  neutral0  neutral1  sad0  sad1  surprise0  \
# ...

# %%
graph1=df.plot.line(subplots=True, figsize=(20,20))

# %%
graph2=df.plot(figsize=(20,20))
graph2.get_figure().savefig("out2.png")

# %%
df=pd.read_csv("../final_df.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\depression-detection\testings\graph.ipynb Cell 7' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/depression-detection/testings/graph.ipynb#ch0000005?line=0'>1</a> df=pd.read_csv("../final_df.csv")
#
# File d:\depression-detection\.venv\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df
# Out:
#    Unnamed: 0 Human Emotions  Emotion Value from the Video
# 0           0          Angry                         49.80
# 1           1        Disgust                          0.07
# 2           2           Fear                          9.56
# 3           3          Happy                         41.33
# 4           4            Sad                         74.04
# 5           5       Surprise                          1.29
# 6           6        Neutral                         79.31

# %%
pie=df.groupby(['Human Emotions']).sum().plot(kind='pie', y='Emotion Value from the Video',figsize=(20,20),title="Emations Percentage Values")

# %%
type(pie)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
pie.get_figure().savefig("out.png")

# %%
df['Emotion Value from the Video'].mean()
# Out:
# 36.48571428571429

# %%
angry=df.loc[df['Human Emotions'] == "Angry", 'Emotion Value from the Video']
sad=df.loc[df['Human Emotions'] == "Sad", 'Emotion Value from the Video']

# %%
angry=df[df['Human Emotions']=="Angry"]['Emotion Value from the Video'].values[0]
sad=df[df['Human Emotions']=="Sad"]['Emotion Value from the Video'].values[0]

# %%
(angry+sad)/2
# Out:
# 61.920000000000016

# %%
happy=df[df['Human Emotions']=="Happy"]['Emotion Value from the Video'].values[0]

# %%
happy
# Out:
# 41.329999999999984
